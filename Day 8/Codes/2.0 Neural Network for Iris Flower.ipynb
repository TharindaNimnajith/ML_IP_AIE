# %%
from sklearn.datasets import load_iris
iris=load_iris()

data=iris.data
target=iris.target

from sklearn.model_selection import train_test_split

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

# %%
import keras.models as models #Models- Neural Networks
import keras.layers as layers#Layers- NN Layers

# %%
model = models.Sequential() #model is a FFNN

model.add(layers.Dense(8,input_dim=4,activation='relu'))
model.add(layers.Dense(3,input_dim=8,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
from sklearn.preprocessing import LabelEncoder

encorder=LabelEncoder()
encorder.fit(train_target)

train_target=encorder.transform(train_target)

from keras.utils import np_utils

train_target=np_utils.to_categorical(train_target)

model.fit(train_data,train_target,epochs=100)
# Out:
# Epoch 1/100
# 135/135 [==============================] - 1s 5ms/step - loss: 3.7976 - acc: 0.3407
# Epoch 2/100
# 135/135 [==============================] - 0s 89us/step - loss: 3.5634 - acc: 0.3407
# Epoch 3/100
# 135/135 [==============================] - 0s 74us/step - loss: 3.3429 - acc: 0.3407
# Epoch 4/100
# 135/135 [==============================] - 0s 103us/step - loss: 3.1298 - acc: 0.3407
# Epoch 5/100
# 135/135 [==============================] - 0s 88us/step - loss: 2.9276 - acc: 0.3407
# Epoch 6/100
# 135/135 [==============================] - 0s 89us/step - loss: 2.7323 - acc: 0.3407
# Epoch 7/100
# 135/135 [==============================] - 0s 96us/step - loss: 2.5540 - acc: 0.3407
# Epoch 8/100
# 135/135 [==============================] - 0s 81us/step - loss: 2.3928 - acc: 0.3407
# Epoch 9/100
# 135/135 [==============================] - 0s 88us/step - loss: 2.2502 - acc: 0.3407
# Epoch 10/100
# ...

# %%
results=model.predict(test_data)

import numpy as np

print(np.argmax(results,axis=1))
print(test_target)
# Out:
# [1 2 1 0 2 0 0 2 2 1 2 2 0 0 1]
# [1 2 1 0 2 0 0 2 1 1 1 2 0 0 1]
